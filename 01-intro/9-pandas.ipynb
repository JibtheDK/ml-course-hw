# %%
import numpy as np
import pandas as pd

# %%
# data frames data structure: basically a table

# %%
data = [
    ['Nissan', 'Stanza', 1991, 138, 4, 'MANUAL', 'sedan', 2000],
    ['Hyundai', 'Sonata', 2017, None, 4, 'AUTOMATIC', 'Sedan', 27150],
    ['Lotus', 'Elise', 2010, 218, 4, 'MANUAL', 'convertible', 54990],
    ['GMC', 'Acadia',  2017, 194, 4, 'AUTOMATIC', '4dr SUV', 34450],
    ['Nissan', 'Frontier', 2017, 261, 6, 'MANUAL', 'Pickup', 32340],
]
 
columns = [
    'Make', 'Model', 'Year', 'Engine HP', 'Engine Cylinders',
    'Transmission Type', 'Vehicle_Style', 'MSRP'
]

# %%
df = pd.DataFrame(data)
df
# Out:
#          0         1     2      3  4          5            6      7
# 0   Nissan    Stanza  1991  138.0  4     MANUAL        sedan   2000
# 1  Hyundai    Sonata  2017    NaN  4  AUTOMATIC        Sedan  27150
# 2    Lotus     Elise  2010  218.0  4     MANUAL  convertible  54990
# 3      GMC    Acadia  2017  194.0  4  AUTOMATIC      4dr SUV  34450
# 4   Nissan  Frontier  2017  261.0  6     MANUAL       Pickup  32340

# %%
# pd.DataFrame(dataset) frames the data
# if we just create it with the data, it dosent know what columns mean, but we can do this..

# %%
df = pd.DataFrame(data, columns = columns) #columns = columns variable 
df
# Out:
#       Make     Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 0   Nissan    Stanza  1991      138.0                 4            MANUAL
# 1  Hyundai    Sonata  2017        NaN                 4         AUTOMATIC
# 2    Lotus     Elise  2010      218.0                 4            MANUAL
# 3      GMC    Acadia  2017      194.0                 4         AUTOMATIC
# 4   Nissan  Frontier  2017      261.0                 6            MANUAL
#
#   Vehicle_Style   MSRP
# 0         sedan   2000
# 1         Sedan  27150
# 2   convertible  54990
# 3       4dr SUV  34450
# 4        Pickup  32340

# %%
df.head(n=2) # gives first n amount of rows
# Out:
#       Make   Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 0   Nissan  Stanza  1991      138.0                 4            MANUAL
# 1  Hyundai  Sonata  2017        NaN                 4         AUTOMATIC
#
#   Vehicle_Style   MSRP
# 0         sedan   2000
# 1         Sedan  27150

# %%
# every column in the dataframe is called a series, if we want to access a specific series, we do..

# %%
df.Make # gives the column make
# Out:
# 0     Nissan
# 1    Hyundai
# 2      Lotus
# 3        GMC
# 4     Nissan
# Name: Make, dtype: str

# %%
df['Make'] # same thing, just useful if you have like for example the 'Engine HP' column since it has a space in the name
# Out:
# 0     Nissan
# 1    Hyundai
# 2      Lotus
# 3        GMC
# 4     Nissan
# Name: Make, dtype: str

# %%
df[['Make','Model','MSRP']] # a list inside the brackets
# Out:
#       Make     Model   MSRP
# 0   Nissan    Stanza   2000
# 1  Hyundai    Sonata  27150
# 2    Lotus     Elise  54990
# 3      GMC    Acadia  34450
# 4   Nissan  Frontier  32340

# %%
# if we want to add a column, we do this:

# %%
df['id'] = [1,2,3,4,5] # id column
df
# Out:
#       Make     Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 0   Nissan    Stanza  1991      138.0                 4            MANUAL
# 1  Hyundai    Sonata  2017        NaN                 4         AUTOMATIC
# 2    Lotus     Elise  2010      218.0                 4            MANUAL
# 3      GMC    Acadia  2017      194.0                 4         AUTOMATIC
# 4   Nissan  Frontier  2017      261.0                 6            MANUAL
#
#   Vehicle_Style   MSRP  id
# 0         sedan   2000   1
# 1         Sedan  27150   2
# 2   convertible  54990   3
# 3       4dr SUV  34450   4
# 4        Pickup  32340   5

# %%
df['id'] = [10,20,30,40,50] # replace col
df
# Out:
#       Make     Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 0   Nissan    Stanza  1991      138.0                 4            MANUAL
# 1  Hyundai    Sonata  2017        NaN                 4         AUTOMATIC
# 2    Lotus     Elise  2010      218.0                 4            MANUAL
# 3      GMC    Acadia  2017      194.0                 4         AUTOMATIC
# 4   Nissan  Frontier  2017      261.0                 6            MANUAL
#
#   Vehicle_Style   MSRP  id
# 0         sedan   2000  10
# 1         Sedan  27150  20
# 2   convertible  54990  30
# 3       4dr SUV  34450  40
# 4        Pickup  32340  50

# %%
del df['Model'] # i deleted make beforehand too
df
# Out:
#    Year  Engine HP  Engine Cylinders Transmission Type Vehicle_Style   MSRP
# 0  1991      138.0                 4            MANUAL         sedan   2000
# 1  2017        NaN                 4         AUTOMATIC         Sedan  27150
# 2  2010      218.0                 4            MANUAL   convertible  54990
# 3  2017      194.0                 4         AUTOMATIC       4dr SUV  34450
# 4  2017      261.0                 6            MANUAL        Pickup  32340

# %%
df.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
df.Year
# Out:
# 0    1991
# 1    2017
# 2    2010
# 3    2017
# 4    2017
# Name: Year, dtype: int64

# %%
# 0 1 2 3 4 is the indexes

# %%
df.loc[1] # loc is location, it gives the row of the specific index
# Out:
# Year                      2017
# Engine HP                  NaN
# Engine Cylinders             4
# Transmission Type    AUTOMATIC
# Vehicle_Style            Sedan
# MSRP                     27150
# Name: 1, dtype: object

# %%
df.loc[[1,2]]
# Out:
#    Year  Engine HP  Engine Cylinders Transmission Type Vehicle_Style   MSRP
# 1  2017        NaN                 4         AUTOMATIC         Sedan  27150
# 2  2010      218.0                 4            MANUAL   convertible  54990

# %%
df.index = ['a','b','c','d','e']

# %%
df.Year
# Out:
# a    1991
# b    2017
# c    2010
# d    2017
# e    2017
# Name: Year, dtype: int64

# %%
# indexes are what i set them to now

# %%
# but you can still get rows from the numerical base indexes with iloc

# %%
df.iloc[[1,2,4]]
# Out:
#    Year  Engine HP  Engine Cylinders Transmission Type Vehicle_Style   MSRP
# b  2017        NaN                 4         AUTOMATIC         Sedan  27150
# c  2010      218.0                 4            MANUAL   convertible  54990
# e  2017      261.0                 6            MANUAL        Pickup  32340

# %%
 df.reset_index() # reset index to numerical and creates a new index column
# Out:
#   index  Year  Engine HP  Engine Cylinders Transmission Type Vehicle_Style  \
# 0     a  1991      138.0                 4            MANUAL         sedan
# 1     b  2017        NaN                 4         AUTOMATIC         Sedan
# 2     c  2010      218.0                 4            MANUAL   convertible
# 3     d  2017      194.0                 4         AUTOMATIC       4dr SUV
# 4     e  2017      261.0                 6            MANUAL        Pickup
#
#     MSRP
# 0   2000
# 1  27150
# 2  54990
# 3  34450
# 4  32340

# %%
df = df.reset_index(drop = True) # resets index AND drops index column
df
# Out:
#    Year  Engine HP  Engine Cylinders Transmission Type Vehicle_Style   MSRP
# 0  1991      138.0                 4            MANUAL         sedan   2000
# 1  2017        NaN                 4         AUTOMATIC         Sedan  27150
# 2  2010      218.0                 4            MANUAL   convertible  54990
# 3  2017      194.0                 4         AUTOMATIC       4dr SUV  34450
# 4  2017      261.0                 6            MANUAL        Pickup  32340

# %%
# element-wise operations now

# %%
df['Engine HP'] / 100   # divides engine hp col by 100
# Out:
# 0    1.38
# 1     NaN
# 2    2.18
# 3    1.94
# 4    2.61
# Name: Engine HP, dtype: float64

# %%
# NaN means missing number

# %%
# you can do any arithematic operation basically, like multiply or divide or add.. wtv

# %%
df['Year'] >= 2015
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4     True
# Name: Year, dtype: bool

# %%
# things of this nature can all be done, this is an example of filtering

# %%
#more on filtering...

# %%
df[
    df['Year'] >= 2015
]
# returns the True values in a new dataframe
# Out:
#    Year  Engine HP  Engine Cylinders Transmission Type Vehicle_Style   MSRP
# 1  2017        NaN                 4         AUTOMATIC         Sedan  27150
# 3  2017      194.0                 4         AUTOMATIC       4dr SUV  34450
# 4  2017      261.0                 6            MANUAL        Pickup  32340

# %%
# combination filtering:
df[
    (df['Year'] >= 2015) & (df['Transmission Type'] == 'AUTOMATIC')
]
# Out:
#    Year  Engine HP  Engine Cylinders Transmission Type Vehicle_Style   MSRP
# 1  2017        NaN                 4         AUTOMATIC         Sedan  27150
# 3  2017      194.0                 4         AUTOMATIC       4dr SUV  34450

# %%
df
# Out:
#    Year  Engine HP  Engine Cylinders Transmission Type Vehicle_Style   MSRP
# 0  1991      138.0                 4            MANUAL         sedan   2000
# 1  2017        NaN                 4         AUTOMATIC         Sedan  27150
# 2  2010      218.0                 4            MANUAL   convertible  54990
# 3  2017      194.0                 4         AUTOMATIC       4dr SUV  34450
# 4  2017      261.0                 6            MANUAL        Pickup  32340

# %%
df.Vehicle_Style
# Out:
# 0          sedan
# 1          Sedan
# 2    convertible
# 3        4dr SUV
# 4         Pickup
# Name: Vehicle_Style, dtype: str

# %%
df.Vehicle_Style.str.lower() # makes everything in the column lowercase
# Out:
# 0          sedan
# 1          sedan
# 2    convertible
# 3        4dr suv
# 4         pickup
# Name: Vehicle_Style, dtype: str

# %%
df.Vehicle_Style.str.replace(' ', '_') # replace spaces with underscores
# Out:
# 0          sedan
# 1          Sedan
# 2    convertible
# 3        4dr_SUV
# 4         Pickup
# Name: Vehicle_Style, dtype: str

# %%
df['Vehicle_Style'] = df.Vehicle_Style.str.replace(' ', '_').str.lower()
df
# Out:
#    Year  Engine HP  Engine Cylinders Transmission Type Vehicle_Style   MSRP
# 0  1991      138.0                 4            MANUAL         sedan   2000
# 1  2017        NaN                 4         AUTOMATIC         sedan  27150
# 2  2010      218.0                 4            MANUAL   convertible  54990
# 3  2017      194.0                 4         AUTOMATIC       4dr_suv  34450
# 4  2017      261.0                 6            MANUAL        pickup  32340

# %%
# summarizing operations now

# %%
df.MSRP
# Out:
# 0     2000
# 1    27150
# 2    54990
# 3    34450
# 4    32340
# Name: MSRP, dtype: int64

# %%
df.MSRP.min
# Out:
# <bound method Series.min of 0     2000
# 1    27150
# 2    54990
# 3    34450
# 4    32340
# Name: MSRP, dtype: int64>

# %%
# ...etc same as numpy. can do .max, .std, etc

# %%
df.MSRP.describe()
# Out:
# count        5.000000
# mean     30186.000000
# std      18985.044904
# min       2000.000000
# 25%      27150.000000
# 50%      32340.000000
# 75%      34450.000000
# max      54990.000000
# Name: MSRP, dtype: float64

# %%
# gives a bunch of useful statistics all in one

# %%
df.describe() # does it for whole dataframe
# Out:
#               Year  Engine HP  Engine Cylinders          MSRP
# count     5.000000    4.00000          5.000000      5.000000
# mean   2010.400000  202.75000          4.400000  30186.000000
# std      11.260551   51.29896          0.894427  18985.044904
# min    1991.000000  138.00000          4.000000   2000.000000
# 25%    2010.000000  180.00000          4.000000  27150.000000
# 50%    2017.000000  206.00000          4.000000  32340.000000
# 75%    2017.000000  228.75000          4.000000  34450.000000
# max    2017.000000  261.00000          6.000000  54990.000000

# %%
df.describe().round(2)
# Out:
#           Year  Engine HP  Engine Cylinders      MSRP
# count     5.00       4.00              5.00      5.00
# mean   2010.40     202.75              4.40  30186.00
# std      11.26      51.30              0.89  18985.04
# min    1991.00     138.00              4.00   2000.00
# 25%    2010.00     180.00              4.00  27150.00
# 50%    2017.00     206.00              4.00  32340.00
# 75%    2017.00     228.75              4.00  34450.00
# max    2017.00     261.00              6.00  54990.00

# %%
# rounds to 2 decimal

# %%
df
# Out:
#    Year  Engine HP  Engine Cylinders Transmission Type Vehicle_Style   MSRP
# 0  1991      138.0                 4            MANUAL         sedan   2000
# 1  2017        NaN                 4         AUTOMATIC         sedan  27150
# 2  2010      218.0                 4            MANUAL   convertible  54990
# 3  2017      194.0                 4         AUTOMATIC       4dr_suv  34450
# 4  2017      261.0                 6            MANUAL        pickup  32340

# %%
df.Year.nunique() # gives the number of unique values in the series
# Out:
# 3

# %%
df.nunique() # gives for whole dataframe
# Out:
# Year                 3
# Engine HP            4
# Engine Cylinders     2
# Transmission Type    2
# Vehicle_Style        4
# MSRP                 5
# dtype: int64

# %%
# missing values now, NaN

# %%
df.isnull() # t/f if there is null value
# Out:
#     Year  Engine HP  Engine Cylinders  Transmission Type  Vehicle_Style   MSRP
# 0  False      False             False              False          False  False
# 1  False       True             False              False          False  False
# 2  False      False             False              False          False  False
# 3  False      False             False              False          False  False
# 4  False      False             False              False          False  False

# %%
df.isnull().sum() # gives num of missing values per series
# Out:
# Year                 0
# Engine HP            1
# Engine Cylinders     0
# Transmission Type    0
# Vehicle_Style        0
# MSRP                 0
# dtype: int64

# %%
# Grouping
df
# Out:
#    Year  Engine HP  Engine Cylinders Transmission Type Vehicle_Style   MSRP
# 0  1991      138.0                 4            MANUAL         sedan   2000
# 1  2017        NaN                 4         AUTOMATIC         sedan  27150
# 2  2010      218.0                 4            MANUAL   convertible  54990
# 3  2017      194.0                 4         AUTOMATIC       4dr_suv  34450
# 4  2017      261.0                 6            MANUAL        pickup  32340

# %%
df.groupby('Transmission Type').MSRP.max()
# Out:
# Transmission Type
# AUTOMATIC    34450
# MANUAL       54990
# Name: MSRP, dtype: int64

# %%
# groups by the transmission type column, and for each group we want to find the max msrp. so automatic max and manual max. 
# can do other functions with this like .std or .min, etc..

# %%
# getting numpy arrays:

# %%
df.MSRP.values
# Out:
# array([ 2000, 27150, 54990, 34450, 32340])

# %%
# returns the underlying numpy array

# %%
df.to_dict(orient = 'records')
# Out:
# [{'Year': 1991,
#   'Engine HP': 138.0,
#   'Engine Cylinders': 4,
#   'Transmission Type': 'MANUAL',
#   'Vehicle_Style': 'sedan',
#   'MSRP': 2000},
#  {'Year': 2017,
#   'Engine HP': nan,
#   'Engine Cylinders': 4,
#   'Transmission Type': 'AUTOMATIC',
#   'Vehicle_Style': 'sedan',
#   'MSRP': 27150},
#  {'Year': 2010,
#   'Engine HP': 218.0,
#   'Engine Cylinders': 4,
#   'Transmission Type': 'MANUAL',
#   'Vehicle_Style': 'convertible',
#   'MSRP': 54990},
#  {'Year': 2017,
#   'Engine HP': 194.0,
#   'Engine Cylinders': 4,
#   'Transmission Type': 'AUTOMATIC',
#   'Vehicle_Style': '4dr_suv',
#   'MSRP': 34450},
#  {'Year': 2017,
#   'Engine HP': 261.0,
#   'Engine Cylinders': 6,
#   'Transmission Type': 'MANUAL',
#   'Vehicle_Style': 'pickup',
#   'MSRP': 32340}]

# %%
# converts dataframe into the OG dictionary. orient is to structure the dictionary into different like things. 
# records is one, dict is the common one, there are others
